# %%
from seleniumbase import Driver
from selenium.webdriver.common.by import By
import time
from time import sleep
import clipboard
import pyperclip as pc
import re
import pyperclip as pc
import pandas as pd
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains

# %%
        #Login no kirk
        id_login = 'glh_oliveira'
        id_pass = 'Mangaverde1.'
        id_loginlans = 'ely_batista'
        id_passlans = 'Ep10162000'
        driver = webdriver.Chrome()
        driver.maximize_window()
        print("solicitação de peças")
        driver.get('https://kirk.magazineluiza.com.br/')
        driver.implicitly_wait(10)
        driver.find_element(By.ID ,"identifier").send_keys(id_login)
        driver.find_element(By.ID ,"password").send_keys(id_pass)
        driver.find_element(By.XPATH ,"/html/body/div/div/view-sign-in/component-card/form/div[2]/button").click()
        driver.implicitly_wait(10)
        time.sleep(6)
        #entra em solicitar serviços
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[3]/a').click()
        #clicar na lupa
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search').click()
        time.sleep(1)
        #solicitação de peças 
        # driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search/button/i').click()
        clipboard.copy('solicitação de peças')
        actions = ActionChains(driver)
        actions.key_down(Keys.CONTROL).send_keys('v')
        actions.perform()
        time.sleep(5)
        #clica no serviço
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/div[2]/div/div[2]/a/component-card/div[2]').click()
        #clica no sim
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[2]/button[1]').click()
        #inicia o preenchimento do formulario
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select').click()
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select/option[2]').click()
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').send_keys('v')
# Out:
# solicitação de peças

# %%
# driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select').click()

driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select').click()
time.sleep(1)
actions = ActionChains(driver)
actions.send_keys('c')
actions.perform()

# %%
#tratativa da planilha
tb_modelo = pd.read_excel("pecas.xlsx")
df2 = tb_modelo.groupby(['Pedido'])['Peca'].apply(lambda x: ','.join(x)).str.split(',',expand=False)
dici = df2.to_dict()
i = 0
pecadiferente = 0

while i in range(len(tb_modelo)):
    try:
                #Login no kirk
        id_login = 'glh_oliveira'
        id_pass = 'Mangaverde1.'
        id_loginlans = 'ely_batista'
        id_passlans = 'Ep10162000'
        driver = webdriver.Chrome()
        driver.maximize_window()
        print("solicitação de peças")
        driver.get('https://kirk.magazineluiza.com.br/')
        driver.implicitly_wait(10)
        driver.find_element(By.ID ,"identifier").send_keys(id_login)
        driver.find_element(By.ID ,"password").send_keys(id_pass)
        driver.find_element(By.XPATH ,"/html/body/div/div/view-sign-in/component-card/form/div[2]/button").click()
        driver.implicitly_wait(10)
        time.sleep(6)
        #entra em solicitar serviços
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[3]/a').click()
        #clicar na lupa
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search').click()
        time.sleep(1)
        #solicitação de peças 
        # driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search/button/i').click()
        clipboard.copy('solicitação de peças')
        actions = ActionChains(driver)
        actions.key_down(Keys.CONTROL).send_keys('v')
        actions.perform()
        time.sleep(5)
        #clica no serviço
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/div[2]/div/div[2]/a/component-card/div[2]').click()
        #clica no sim
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[2]/button[1]').click()
        #inicia o preenchimento do formulario
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select').click()
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select/option[2]').click()
        


        pedido = tb_modelo['Pedido'].values[i]
        pedido = str(pedido)
        codigo_produto = tb_modelo['Cod_produto'].values[i]
        os = tb_modelo['OS'].values[i]
        codigo_produto = str(codigo_produto)
        os = str (os)
        print(pedido)
        pecadiferente = 0
        pecadiferente=(len(dici[tb_modelo['Pedido'].values[i]]))
        motivopeca = tb_modelo['Motivo'].values[i]
        if str(motivopeca) == "Montagem":
                avaria = "Peça extraviada"
                print(avaria)
        if str(motivopeca) == "Fornecedor":
                avaria = "Falta peça"
                print(avaria)
        else :
                avaria = "Arrastrou produto"
                print(avaria)
        driver.implicitly_wait(10)
        time.sleep(1)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').send_keys(pedido)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').send_keys(pedido)
        time.sleep(10)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[6]/div[1]/input').click()
        time.sleep(10)
##seleciona o codigo do produto
        # Encontre todos os botões dentro do elemento pai
        buttons = driver.find_elements(By.CSS_SELECTOR, ".vui-TextField-AutocompleteResult .item")
        # Valor que você deseja encontrar

        # Percorra todos os botões e clique naquele que contém o valor desejado
        try:
            for button in buttons:
                if button.text == codigo_produto:
                    time.sleep(5)
                    button.click()
        except:
            print("foi")      
#seleciona o codigo da OS
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[7]/div[1]/input').click()
        time.sleep(1)

        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[8]/div[1]/input').click()
        time.sleep(1)
        buttons = driver.find_elements(By.CSS_SELECTOR, "#vuiAutocompleteResult > div > div > button")

        try:
            for button in buttons:
                    if button.text == os:
                        button.click()
        except:
            print("foi")
#quantidade de peças diferentes
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[42]/div[1]/input').send_keys(pecadiferente)
            
#inicio do preenchimento de peças        
        
        contador = 9
        redutordei = pecadiferente
        while pecadiferente >=1 and pecadiferente >0:
            print(pecadiferente)
            print(i)
            contador = i
            if contador == 0:
                #pedido = (tb_modelo.loc[i, 'Pedido'])
                peca = (tb_modelo.loc[i, 'Peca'])
                qtdpeca = tb_modelo['qtdpeca'].values[i]
                qtdpeca = str(qtdpeca)
                contador = contador+1

            elif contador >= 1:
                if tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido']:
                    #print(tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido'])
                    #print(i, i-1)
                    #pedido = (tb_modelo.loc[i, 'Pedido'])
                    peca = (tb_modelo.loc[i, 'Peca'])
                    qtdpeca = tb_modelo['qtdpeca'].values[i]
                    qtdpeca = str(qtdpeca)
                    contador = contador+1
                    #print(pecadiferente)


                else:
    #                 print(tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido'])
    #                 print(i, i-1)
                    #pedido = (tb_modelo.loc[i, 'Pedido'])
                    peca = (tb_modelo.loc[i, 'Peca'])
                    qtdpeca = tb_modelo['qtdpeca'].values[i]
                    qtdpeca = str(qtdpeca)
                    contador = contador+1

            elemento_base = 44
            for inter in pecadiferente:
                driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base}]/div[1]/input').click()
                
                time.sleep(5)
                buttons = driver.find_elements(By.CSS_SELECTOR, ".vui-TextField-AutocompleteResult .item")

                try:
                    for button in buttons:
                            if button.text == peca:
                                button.click()
                except:
                    print("selecionou peça")
                driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+1}]/div[1]/input').send_keys(qtdpeca)
                driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+2}]/div[1]/select').click()
                time.sleep(5)
                driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+3}]/div[1]/select').send_keys(motivopeca)
                driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+4}]/div[1]/select').send_keys(avaria)
                elemento_base +=7
                pecadiferente = pecadiferente -1
                i = i+1
            break        
        
            if pecadiferente ==1:
                driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[44]/div[1]/input').click()
                
                time.sleep(5)
                buttons = driver.find_elements(By.CSS_SELECTOR, ".vui-TextField-AutocompleteResult .item")

                try:
                    for button in buttons:
                            if button.text == peca:
                                button.click()
                except:
                    print("selecionou peça")
                driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[45]/div[1]/input').send_keys(qtdpeca)
                driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[46]/div[1]/select').click()
                time.sleep(5)
                driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[46]/div[1]/select').send_keys(motivopeca)
                driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[47]/div[1]/select').send_keys(avaria)
        
                
                pecadiferente = pecadiferente -1
                i = i+1
                break         
            elif pecadiferente ==2:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 2 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[57]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca2 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[58]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca2 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[59]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 2
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[60]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1

            elif pecadiferente ==3:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 3 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[64]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca3 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[65]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca3
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[66]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 3
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[67]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==4:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 4 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[71]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca4 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[72]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca4
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[73]/div/div[1]/div[1]/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 4
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[74]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==5:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 5 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[78]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca5 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[79]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca5
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[80]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 5
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[81]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==6:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 6 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[85]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca6 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[86]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca6
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[87]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 6
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[88]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==7:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 7 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[92]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca7 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[93]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca7
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[94]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 7
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[95]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==8:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 8 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[99]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca8 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[100]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca8
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[101]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 8
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[102]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            elif pecadiferente ==9:
    #             print(pedido)
    #             print(motivopeca)
    #             print(avaria)
    #             print(peca)
    #             print(qtdpeca)
                #peça 9 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[106]/div/div[1]/div/input').send_keys(peca)
                time.sleep(1)
                pyautogui.press('right')
                pyautogui.press('backspace')
                time.sleep(1)
                pyautogui.press('enter')
                time.sleep(1)
                #qqtdepeca9 
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[107]/div/div[1]/input').send_keys(qtdpeca)
                pyautogui.press('tab')
                time.sleep(1)
                #motivopeca9
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[108]/div/div[1]/div/input').send_keys(motivopeca)  
                pyautogui.press('tab')
                driver.implicitly_wait(10)
                time.sleep(1)
                #avaria peça 9
                driver.find_element(By.XPATH ,'/html/body/div[4]/div[2]/div/div[3]/div/div[1]/div[1]/div/div/div[1]/div/div/div[3]/div[2]/div[1]/div/div[109]/div/div[1]/div/input').send_keys(avaria)
                pyautogui.press('tab')
                pecadiferente = pecadiferente -1
                i = i+1
            else: 
                print("Acabou ou peçs diferentes maior que 9")
    #             i = i+1
    #     driver.find_element(By.ID ,"ext-gen256").click()
    #     chamado = driver.find_element(By.XPATH, '/html/body/div[22]/div[2]/div[1]/div/div/div/div/div[2]/span').get_attribute('textContent')
    #     print (chamado)
    #     driver.get('https://magazineluiza.lansolver.com/')
    #     driver.implicitly_wait(10)
    #     driver.find_element(By.ID ,"email").send_keys(id_loginlans)
    #     driver.find_element(By.ID ,"password").send_keys(id_passlans)
    #     driver.find_element(By.ID ,"buttonLogin").click()
    #     driver.implicitly_wait(10)
    #     time.sleep(1)
    #     driver.find_element(By.ID ,"prosseguir_btn").click()
    #     driver.find_element(By.XPATH ,'/html/body/div/div[2]/div/div/div/div[2]/div[4]/div/div[1]/div[1]/div[2]/input').send_keys(os)
    #     time.sleep(5)
    #     pyautogui.press('enter')
    #     driver.implicitly_wait(10)
    #     time.sleep(5)

    #     driver.find_element(By.XPATH ,'/html/body/div/div[2]/div/div/div/div[2]/div[4]/div/div[1]/div[2]/div[2]/table/tbody/tr/td[3]').click()
    #     driver.implicitly_wait(10)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div/b/b/form/div/div[2]/div[3]/div/div/div[1]/div/div/div[3]/div/a').click()
    #     driver.implicitly_wait(10)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div/b/b/form/div/div[2]/div[3]/div/div/div[2]/div[4]/div/a').click()
    #     driver.implicitly_wait(10)
    #     time.sleep(1)
    #     ###############################################################################################################################################################################################
    #     driver.find_element(By.XPATH ,'/html/body/div[1]/b/b/div[10]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[9]/div/div/div[3]/div[2]').click()
    #     driver.implicitly_wait(30)
    #     time.sleep(1)
    #     # driver.find_element(By.XPATH ,'/html/body/div[1]/div[9]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[9]/div/div/div[3]/div[2]').click()
    #     #driver.find_element(By.XPATH ,'/html/body/div[1]/div[8]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[9]/div/div/div[3]/div[2]').send_keys(chamado)
    #     clipboard.copy(chamado)
    #     pyautogui.hotkey('ctrl','v')        
    #     # driver.implicitly_wait(30)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div[1]/b/b/div[10]/div/div/div[3]/button[3]').click()
    #     driver.implicitly_wait(10)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div/b/b/form/div/div[3]/div[2]/button[2]').click()
    #     driver.implicitly_wait(30)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div/b/b/form/div/div[2]/div[2]/div/div[4]/div[1]/span/span[1]/span/span[1]').click()
    #     driver.implicitly_wait(30)
    #     time.sleep(1)
    #     clipboard.copy('PEÇAS - SOLICITADAS')
    #     pyautogui.hotkey('ctrl','v')
    #     driver.implicitly_wait(30)
    #     time.sleep(1)
    #     pyautogui.press('enter')
    #     driver.find_element(By.XPATH ,'/html/body/div/b/b/form/div/div[3]/div[3]/button[1]').click()
    #     driver.implicitly_wait(300)
    #     time.sleep(1)
    #     driver.find_element(By.XPATH ,'/html/body/div[1]/b/b/div[27]/div/div/div[3]/button[1]').click()
    #     driver.quit()
    # except Exception as err:
    #     print('Não foi possivel prosseguir')
    #     break
    #     driver.quit()
# Out:
# solicitação de peças
# 902226950
# Falta peça
# foi
# 1
# 0
# solicitação de peças
# solicitação de peças
# 902226950
# Falta peça
# solicitação de peças
# 902226950
# Falta peça
# foi
# 1
# 0
# solicitação de peças
# solicitação de peças
# solicitação de peças
# solicitação de peças

# %%
peca
# Out:
# '09032-FRENTE GAVETA'

# %%
# time.sleep(5)
# buttons = driver.find_elements(By.CSS_SELECTOR, "vui-TextField vui-Field is-focused is-filled is-required")

# try:
#     for button in buttons:
#             if button.text == motivopeca:
#                 button.click()
# except:
#     print("motivo da avaria")
