# %%
#importações
from seleniumbase import Driver
from selenium.webdriver.common.by import By
import time
from time import sleep
import clipboard
import pyperclip as pc
import re
import pyperclip as pc
import pandas as pd
from selenium.webdriver.chrome.options import Options
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.support.ui import WebDriverWait
from key import *
from selenium.webdriver.support import expected_conditions as EC

# %%
#função para preencher os dados das peças
def preenche_peca(pecadiferente, peca,qtdpeca,motivopeca,avaria):
    print("iniciou a função")
    elemento_base = 44
    for inter in range(pecadiferente):
        driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base}]/div[1]/input').click()
        
        time.sleep(5)
        buttons = driver.find_elements(By.CSS_SELECTOR, ".vui-TextField-AutocompleteResult .item")

        try:
            for button in buttons:
                    if button.text == peca:
                        button.click()
        except:
            print("selecionou peça")
        driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+1}]/div[1]/input').send_keys(qtdpeca)
        print(qtdpeca)
        driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+2}]/div[1]/select').click()
        time.sleep(5)
        driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+2}]/div[1]/select').send_keys(motivopeca)
        
        print(motivopeca)
        driver.find_element(By.XPATH ,f'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[{elemento_base+3}]/div[1]/select').send_keys(avaria)
        print(avaria)
        elemento_base +=7
    elemento_base = 44
    pecadiferente = 0
    return pecadiferente

# %%
#função lansolver
def lansolver(chamado_value,os):

    driver.get('https://magazineluiza.lansolver.com/')
    driver.implicitly_wait(10)
    driver.find_element(By.ID ,"email").send_keys(id_loginlans)
    driver.find_element(By.ID ,"password").send_keys(id_passlans)
    driver.find_element(By.ID ,"buttonLogin").click()
    driver.implicitly_wait(10)
    time.sleep(1)
    driver.find_element(By.ID ,"prosseguir_btn").click()
    try:
        driver.find_element(By.XPATH ,'/html/body/div/div[2]/div/div/div/div[2]/div[4]/div/div[1]/div[1]/div[2]/input').send_keys(os)
    except:
        driver.find_element(By.XPATH ,'/html/body/b/b/div[3]/div/div/div/div[2]/div[4]/div/div[1]/div[1]/div[2]/input').send_keys(os)
    time.sleep(5)
    actions = ActionChains(driver)
    actions.key_down(Keys.ENTER)
    actions.perform()
    driver.implicitly_wait(10)
    time.sleep(5)
    try:
        driver.find_element(By.XPATH ,'/html/body/div/div[3]/div/div/div/div[2]/div[4]/div/div[1]/div[2]/div[2]/table/tbody/tr/td[3]').click()
    except:
        driver.find_element(By.XPATH ,'/html/body/b/b/div[3]/div/div/div/div[2]/div[4]/div/div[1]/div[2]/div[2]/table/tbody').click()
    driver.implicitly_wait(10)
    time.sleep(1)
    driver.find_element(By.XPATH ,'/html/body/b/b/form/div/div[2]/div[3]/div/div/div[1]/div/div/div[3]/div/a').click()
    driver.implicitly_wait(10)
    time.sleep(1)
                                    
    driver.find_element(By.XPATH ,'/html/body/b/b/form/div/div[2]/div[3]/div/div/div[2]/div[4]/div/a').click()
    driver.implicitly_wait(10)
    time.sleep(1)
    ###############################################################################################################################################################################################
    driver.find_element(By.XPATH ,'/html/body/b/b/div[9]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[10]/div/div/div[3]/div[2]').click()
    driver.implicitly_wait(30)
    time.sleep(1)
    # driver.find_element(By.XPATH ,'/html/body/div[1]/div[9]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[9]/div/div/div[3]/div[2]').click()
    #driver.find_element(By.XPATH ,'/html/body/div[1]/div[8]/div/div/div[2]/div/div/div/div[2]/div[1]/div/div[9]/div/div/div[3]/div[2]').send_keys(chamado)
    clipboard.copy(chamado_value)
    actions = ActionChains(driver)
    actions.key_down(Keys.CONTROL).send_keys('v')
    actions.perform()      
    # driver.implicitly_wait(30)
    time.sleep(1)
    driver.find_element(By.XPATH ,'/html/body/b/b/div[9]/div/div/div[3]/button[3]').click()
    driver.implicitly_wait(10)
    time.sleep(1)
    driver.find_element(By.XPATH ,'/html/body/b/b/form/div/div[3]/div[2]/button[2]').click()
    driver.implicitly_wait(30)
    time.sleep(1)
    driver.find_element(By.XPATH ,'/html/body/b/b/form/div/div[2]/div[2]/div/div[4]/div[1]/span/span[1]/span/span[1]').click()
    driver.implicitly_wait(30)
    time.sleep(1)
    clipboard.copy('PEÇAS - SOLICITADAS')
    actions = ActionChains(driver)
    actions.key_down(Keys.CONTROL).send_keys('v')
    actions.perform()  
    driver.implicitly_wait(30)
    time.sleep(1)
    actions = ActionChains(driver)
    actions.key_down(Keys.ENTER)
    actions.perform()  
    driver.find_element(By.XPATH ,'/html/body/b/b/form/div/div[3]/div[3]/button[1]').click()
    driver.implicitly_wait(30)
    time.sleep(1)
    driver.find_element(By.XPATH ,'/html/body/b/b/div[26]/div/div/div[3]/button[1]').click()
    driver.quit()

# %%
#tratativa da planilha
tb_modelo = pd.read_excel("pecas.xlsx")
df2 = tb_modelo.groupby(['Pedido'])['Peca'].apply(lambda x: ','.join(x)).str.split(',',expand=False)
dici = df2.to_dict()
i = 0
pecadiferente = 0

while i in range(len(tb_modelo)):
    try:
                #Login no kirk
        id_login = id_login
        id_pass = id_pass
        id_loginlans = id_loginlans
        id_passlans = id_passlans
        driver = webdriver.Chrome()
        driver.maximize_window()
        print("solicitação de peças")
        driver.get('https://kirk.magazineluiza.com.br/')
        driver.implicitly_wait(10)
        driver.find_element(By.ID ,"identifier").send_keys(id_login)
        driver.find_element(By.ID ,"password").send_keys(id_pass)
        driver.find_element(By.XPATH ,"/html/body/div/div/view-sign-in/component-card/form/div[2]/button").click()
        driver.implicitly_wait(10)
        time.sleep(6)
        #entra em solicitar serviços
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[3]/a').click()
        #clicar na lupa
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search').click()
        time.sleep(1)
        #solicitação de peças 
        # driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/super-bar/div/component-search/button/i').click()
        clipboard.copy('solicitação de peças')
        actions = ActionChains(driver)
        actions.key_down(Keys.CONTROL).send_keys('v')
        actions.perform()
        time.sleep(5)
        #clica no serviço
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/div/div[4]/view-services/div[2]/div/div[2]/a/component-card/div[2]').click()
        #clica no sim
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[2]/button[1]').click()
        #inicia o preenchimento do formulario
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select').click()
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[3]/div/select/option[2]').click()
        


        pedido = tb_modelo['Pedido'].values[i]
        pedido = str(pedido)
        codigo_produto = tb_modelo['Cod_produto'].values[i]
        os = tb_modelo['OS'].values[i]
        codigo_produto = str(codigo_produto)
        os = str (os)
        print(pedido)
        pecadiferente = 0
        pecadiferente=(len(dici[tb_modelo['Pedido'].values[i]]))
        motivopeca = tb_modelo['Motivo'].values[i]
        if str(motivopeca) == "Montagem":
                avaria = "Peça extraviada"
                print(avaria)
        if str(motivopeca) == "Fornecedor":
                avaria = "Falta peça"
                print(avaria)
        else :
                avaria = "Arrastrou produto"
                print(avaria)
        driver.implicitly_wait(10)
        time.sleep(1)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').click()
        time.sleep(1)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').send_keys(pedido)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[5]/div[1]/input').send_keys(pedido)
        time.sleep(10)
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[6]/div[1]/input').click()
        time.sleep(10)
        ##seleciona o codigo do produto
        # Encontre todos os botões dentro do elemento pai
        try:
            buttons = driver.find_elements(By.CSS_SELECTOR, ".vui-TextField-AutocompleteResult .item")
        # Valor que você deseja encontrar

        # Percorra todos os botões e clique naquele que contém o valor desejado
            for button in buttons:
                if button.text == codigo_produto:
                    time.sleep(6)
                    button.click()
        except:
            print("foi")      
        #seleciona o codigo da OS
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[7]/div[1]/input').click()
        time.sleep(1)

        try:
            driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[8]/div[1]/input').click()
            time.sleep(1)
            buttons = driver.find_elements(By.CSS_SELECTOR, "#vuiAutocompleteResult > div > div > button")

            for button in buttons:
                    if button.text == os:
                        button.click()
        except:
            print("foi")
#quantidade de peças diferentes
        driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[1]/div[42]/div[1]/input').send_keys(pecadiferente)
            
#inicio do preenchimento de peças        
        
        contador = 9
        redutordei = pecadiferente
        while pecadiferente >=1 and pecadiferente >0:
            print(pecadiferente)
            print(i)
            contador = i
            if contador == 0:
                #pedido = (tb_modelo.loc[i, 'Pedido'])
                peca = (tb_modelo.loc[i, 'Peca'])
                qtdpeca = tb_modelo['qtdpeca'].values[i]
                qtdpeca = str(qtdpeca)
                contador = contador+1

            elif contador >= 1:
                if tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido']:
                    #print(tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido'])
                    #print(i, i-1)
                    #pedido = (tb_modelo.loc[i, 'Pedido'])
                    peca = (tb_modelo.loc[i, 'Peca'])
                    qtdpeca = tb_modelo['qtdpeca'].values[i]
                    qtdpeca = str(qtdpeca)
                    contador = contador+1
                    #print(pecadiferente)


                else:
    #                 print(tb_modelo.loc[i, 'Pedido'] == tb_modelo.loc[i -1, 'Pedido'])
    #                 print(i, i-1)
                    #pedido = (tb_modelo.loc[i, 'Pedido'])
                    peca = (tb_modelo.loc[i, 'Peca'])
                    qtdpeca = tb_modelo['qtdpeca'].values[i]
                    qtdpeca = str(qtdpeca)
                    contador = contador+1
            print("chegou para iniciar a funçao")
            pecadiferente = preenche_peca(pecadiferente, peca,qtdpeca,motivopeca,avaria)
            
            i = i+1
            driver.find_element(By.XPATH ,'/html/body/div[1]/div/component-dialog-container/component-dialog/div/component-card/div/form/div[2]/div/div[2]/button[3]').click()
            time.sleep(10)
            # Espera até que o elemento esteja presente e visível na página
            try:
                driver.find_element(By.XPATH, '/html/body/div[1]/div/div/div[4]/view-tasks/div[2]/div[2]/component-card/component-meta-form/div[1]/div[1]/span').click()
                element = WebDriverWait(driver, 10).until(
                    EC.visibility_of_element_located((By.XPATH, '/html/body/div[1]/div/div/div[4]/view-tasks/div[2]/div[2]/component-card/component-meta-form/div[1]/div[1]/span'))
                )

                # Tenta pegar o valor do atributo 'value'
                chamado_value = element.get_attribute('value')
                
                # Se o valor for None, tenta pegar o texto do elemento
                if chamado_value is None:
                    chamado_value = element.text

                # Adiciona o código para pegar o valor do IDK
                idk_element = driver.find_element(By.XPATH, "//div[@class='card-detail']//div[contains(text(),'IDK')]/span")
                idk_value = idk_element.text
                print(f"O valor do IDK é: {idk_value}")

            except Exception as e:
                chamado_value = ''
                print("Não consegui pegar o idk, vou pegar na função")
                print(f"Erro: {e}")


            print("O valor do elemento é:", chamado_value)
            lansolver(chamado_value,os)
            
    except Exception as e:
        driver.quit()
        print(f"Erro: {e}")
# Out:
# solicitação de peças
# 902226950
# Falta peça
# foi
# 1
# 0
# chegou para iniciar a funçao
# iniciou a função
# 2
# Erro: Message: element click intercepted: Element <select class="input" id="707825" name="motivo_da_avaria_1" type="text" required="">...</select> is not clickable at point (678, 373). Other element would receive the click: <button class="item vui-TextField-Autocomplete-Target616" tabindex="0">...</button>
#   (Session info: chrome=125.0.6422.76)
# Stacktrace:
# #0 0x63cb2b0fce9a <unknown>
# #1 0x63cb2ade645c <unknown>
# #2 0x63cb2ae39336 <unknown>
# #3 0x63cb2ae37176 <unknown>
# #4 0x63cb2ae34b57 <unknown>
# #5 0x63cb2ae3397c <unknown>
# #6 0x63cb2ae270ff <unknown>
# #7 0x63cb2ae554b2 <unknown>
# #8 0x63cb2ae26a79 <unknown>
# #9 0x63cb2ae5567e <unknown>
# #10 0x63cb2ae742cc <unknown>
# #11 0x63cb2ae55253 <unknown>
# #12 0x63cb2ae251c7 <unknown>
# #13 0x63cb2ae25b3e <unknown>
# #14 0x63cb2b0c32db <unknown>
# #15 0x63cb2b0c7387 <unknown>
# #16 0x63cb2b0afe0e <unknown>
# ...
